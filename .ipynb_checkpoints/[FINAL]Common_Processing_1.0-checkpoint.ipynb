# %% [markdown]
# #### #### README
#  - **Topic: Employee Churn Prediction Modeling**
#  - **This document: Common Processing / Reusable codes**
#  - **Next document: [FINAL]Modeling.ipynb**

# %% [markdown]
# ## ## Settings

# %% [markdown]
# #### Display

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #### Packages

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### UDF

# %%
def null_check_for_loop(df):
    all_null_sum = 0
    for col in df.columns :        
        all_null_sum = all_null_sum + df[col].isnull().sum()
    if all_null_sum == 0:
        print('There is no null value in this DataFrame.')
    else:
        for col in df.columns :
            print("{:.2f}% : column '{}'".format(100*(df[col].isnull().sum() / df[col].shape[0]), col))

def dov(df):
    display(df.shape, df.head(2))

# %% [markdown]
# ## ## Data Overview

# %%
d_orig = pd.read_csv('./data/employee_attrition_ibm_data.csv')
d = d_orig.copy()
dov(d)
# Out:
# (1470, 35)
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
# d.head(5).T

# %% [markdown]
# #### null check

# %%
# null_check_msno_bar(d)

# %%
# null_check_for_loop(d)

# %%
null_check_for_loop(d)
# Out:
# There is no null value in this DataFrame.

# %% [markdown]
# #### peek

# %%
# d.info()

# %%
d.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %% [markdown]
# #### target variable

# %%
d.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
d.Attrition.value_counts().plot(kind='bar')

# %% [markdown]
# # ## Basic Common Processing

# %% [markdown]
# #### Target variable & Useless Columns

# %%
# Reassign target
d.Attrition.replace(to_replace = dict(Yes = 1, No = 0), inplace = True)

# Find the useless features
li_useless_feat = []
for col in list(d.columns):
    if d[col].nunique() == 1:
        li_useless_feat.append(col)
print('Useless Features:{}'.format(li_useless_feat))

# Delete the useless features
d.drop(columns=li_useless_feat, inplace=True)
d.head(2)
# Out:
# Useless Features:['EmployeeCount', 'Over18', 'StandardHours']
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# 1                        3  ...                 4                         4
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                 0                  8                     0                1
# 1                 1                 10                     3                3
#
# ...

# %% [markdown]
# #### Generation-related Columns & Data Split
#  - Generation-related Columns: [aaa, bbb, ccc]
#  - Data Split: [data_gen_x, data_gen_y, data_gen_z]

# %%
def age_to_born_yyyy(x):
    return 2015 - x

def cat_generation(x):
    if (x>=1940) & (x<=1959):
        return 'gen_baby_boomer'
    elif (x>=1960) & (x<=1979):
        return 'gen_x'
    elif (x>=1980) & (x<=1994):
        return 'gen_y'
    elif (x>=1995) & (x<=2010):
        return 'gen_z'
    else:
        return 'gen_alpha'

# %%
# Add generation-related columns
d['born_yyyy'] = d.Age.apply(age_to_born_yyyy)
d['generation'] = d.born_yyyy.apply(cat_generation)

# %%
display(
    np.round(d.generation.value_counts()/len(d)*100, 2),
    d.head(2)
)
# Out:
# gen_y              47.69
# gen_x              47.21
# gen_baby_boomer     3.20
# gen_z               1.90
# Name: generation, dtype: float64
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
#
#    EnvironmentSatisfaction  ... StockOptionLevel  TotalWorkingYears  \
# 0                        2  ...                0                  8
# 1                        3  ...                1                 10
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1              6                   4
# ...

# %%
d.to_csv('./data/data_pped_2.0.csv', index=False, header=True)

# %%
# separate the dataframe regarding generations
d_x = d[d.generation=='gen_x'].reset_index(drop=True)
d_y = d[d.generation=='gen_y'].reset_index(drop=True)
d_z = d[d.generation=='gen_z'].reset_index(drop=True)

# separate the data
d_x.to_csv('./data/gen_x_data.csv', index=False, header=True)
d_y.to_csv('./data/gen_y_data.csv', index=False, header=True)
d_z.to_csv('./data/gen_z_data.csv', index=False, header=True)

# %% [markdown]
# ## ## Reading data / gen_x, gen_y, gen_z

# %%
display(
    pd.read_csv('./data/gen_x_data.csv').head(2),
    pd.read_csv('./data/gen_y_data.csv').head(2),
    pd.read_csv('./data/gen_z_data.csv').head(2)
)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
#
#    EnvironmentSatisfaction  ... StockOptionLevel  TotalWorkingYears  \
# 0                        2  ...                0                  8
# 1                        3  ...                1                 10
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1              6                   4
# 1                      3                3             10                   7
#
#   YearsSinceLastPromotion  YearsWithCurrManager  born_yyyy  generation
# ...
